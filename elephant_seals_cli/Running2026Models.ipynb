# %%
from roboflow import Roboflow
import os

# %%
api_key = os.environ.get("ROBOFLOW_API_KEY")
rf = Roboflow(api_key=api_key)
project = rf.workspace().project('elephant-seals-project-mark-1')
# Out:
# loading Roboflow workspace...
# loading Roboflow project...

# %% [markdown]
# Running Version 21 of the Roboflow Model

# %%
model21 = project.version("21").model #changed to version 21 for Connor Model

# %%
print("Using Roboflow version:", "21")  #where i left off
pred1 = model21.predict("ClassifiedImage1.tif").json()
#result1 = pred1.get("predictions", {})
#print(result1)
#for seal_sex, confidence in result1.items():
#    percentage = confidence * 100
#    print(f"{seal_sex} - {percentage:.0f}%")#my code
pred2 = model21.predict("ClassifiedImage2.tif").json() #my code
pred3 = model21.predict("ClassifiedImage3.tif").json() #my code
pred4 = model21.predict("ClassifiedImage4.tif").json() #my code
pred5= model21.predict("ClassificationImage5.tif").json() #my code
# Out:
# Using Roboflow version: 21

# %%
print("prediction 1: ")
print(pred1) #my code
print("prediction 2: ")
print(pred2)
print("prediction 3: ")
print(pred3)
print("prediction 4: ")
print(pred4)
print("prediction 5: ")
print(pred5)
# Out:
# prediction 1:
# {'predictions': [{'x': 113, 'y': 68, 'width': 69, 'height': 18, 'confidence': 0.7704784870147705, 'class': 'Pup', 'class_id': 4, 'detection_id': '8454afaa-fe3f-43b6-80c9-ed4bab1c6f2f', 'image_path': 'ClassifiedImage1.tif', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '386', 'height': '296'}}
# prediction 2:
# {'predictions': [], 'image': {'width': '386', 'height': '318'}}
# prediction 3:
# {'predictions': [{'x': 162, 'y': 97, 'width': 212, 'height': 57, 'confidence': 0.7376883029937744, 'class': 'Adult Male', 'class_id': 1, 'detection_id': 'aec36994-e31c-4a2d-be42-d8308a5cefa4', 'image_path': 'ClassifiedImage3.tif', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '484', 'height': '352'}}
# prediction 4:
# ...

# %% [markdown]
# Running Version 23 of the Roboflow Model

# %%
model23 = project.version("23").model #changed to version 23 for Connor Model

# %%
print("Using Roboflow version:", "23")  #where i left off
pred1 = model23.predict("ClassifiedImage1.tif").json() #my code
#predictions = pred1.get("predictions", [])
#print("Confidence levels: ")
#for pred in predictions:
    #print(pred)

    #seal_class = pred["class"]
    #confidence = pred["confidence"]
    #print(f"{seal_class} - {confidence*100:.0f}%")
#result1 = pred1.get("predictions", {})
#predictions = result1.get("predictions", [])

#print("Confidence Levels:")
#for pred in predictions:
    #seal_sex = pred["class"]
    #confidence = pred["confidence"]

    # Convert to percentage
    #percentage = confidence * 100
    #print(f"{seal_sex} - {percentage:.0f}%")




#print(result1)
#for seal_sex, confidence in result1.items():
    #percentage = confidence * 100
    #print(f"{seal_sex} - {percentage:.0f}%")#my code


pred2 = model23.predict("ClassifiedImage2.tif").json() #my code
pred3 = model23.predict("ClassifiedImage3.tif").json() #my code
pred4 = model23.predict("ClassifiedImage4.tif").json() #my code
pred5= model23.predict("ClassificationImage5.tif").json() #my code
# Out:
# Using Roboflow version: 23

# %%
print(pred1)
# Out:
# {'predictions': [{'x': 114, 'y': 48, 'width': 229, 'height': 96, 'confidence': 0.7699276804924011, 'class': 'Adult Male', 'class_id': 2, 'detection_id': '2708d253-a9a6-4fd6-a628-616899bc1adf', 'image_path': 'ClassifiedImage1.tif', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '386', 'height': '296'}}

# %%
result1 = pred1.get("predictions", {})
print(result1)
for detection in result1:
    seal_sex = detection["class"]
    confidence = detection["confidence"]
    percentage = confidence * 100

    print(f"{seal_sex} - {percentage:.0f}%")
# Out:
# [{'x': 114, 'y': 48, 'width': 229, 'height': 96, 'confidence': 0.7699276804924011, 'class': 'Adult Male', 'class_id': 2, 'detection_id': '2708d253-a9a6-4fd6-a628-616899bc1adf', 'image_path': 'ClassifiedImage1.tif', 'prediction_type': 'ObjectDetectionModel'}]
# Adult Male - 77%

# %%
print("prediction 1: ")
print(pred1) #my code
print("prediction 2: ")
print(pred2)
print("prediction 3: ")
print(pred3)
print("prediction 4: ")
print(pred4)
print("prediction 5: ")
print(pred5)
# Out:
# prediction 1:
# {'predictions': [{'x': 114, 'y': 48, 'width': 229, 'height': 96, 'confidence': 0.7699276804924011, 'class': 'Adult Male', 'class_id': 2, 'detection_id': '2708d253-a9a6-4fd6-a628-616899bc1adf', 'image_path': 'ClassifiedImage1.tif', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '386', 'height': '296'}}
# prediction 2:
# {'predictions': [], 'image': {'width': '386', 'height': '318'}}
# prediction 3:
# {'predictions': [{'x': 162, 'y': 96, 'width': 214, 'height': 53, 'confidence': 0.945516049861908, 'class': 'Adult Male', 'class_id': 2, 'detection_id': '5b7ad151-bbaa-4688-9cd3-af4928259530', 'image_path': 'ClassifiedImage3.tif', 'prediction_type': 'ObjectDetectionModel'}], 'image': {'width': '484', 'height': '352'}}
# prediction 4:
# ...
